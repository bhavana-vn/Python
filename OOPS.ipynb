# %% [markdown]
# OOPS:
# -----
# _______________
#
# 1. oops stands for an object oriented programming language
# 2. which is used to build the modular,scalable and maintable programs
# 3. It also helps in organizing the code  into classes and objects
# 4. It supports encapsulations to group the data and methods
# 5. Supports inheritence for code reusability and hirarchy
# 6. enables the polymorphysm for flexible method implementation

# %% [markdown]
# Class:
# ======
#
# class is a blueprint which is used to create an object.
#
# Object:
# ======
#
# an object is an instance of a class

# %% [markdown]
# Encapsulation:
# --------------------
# encapsulation means binding the data(variables) and methods together into a single unit (class) and restrictng direct access to the data.

# %%
	#customer should not directly change the balance

class BankAccount:
					def __init__(self,balance):
										self.__balance=balance
					
					def deposit(self, amount):
										if amount>0:
															self.__balance+=amount
															print(f'{self.__balance}')	
												
					def withdraw(self,amount):
										if  0<amount<=self.__balance:
															self.__balance-=amount
															print(f'{self.__balance}')											
										else:
															print("insufficent balance")
													
					def  check_balance(self):
												print(self.__balance)
									
sbi=BankAccount(0)
sbi.deposit(2000)
sbi.withdraw(100)
# Out:
# 2000
# 1900
